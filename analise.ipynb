# %% [markdown]
# #### Essa é a versão notebook da análise, caso necessário

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pycountry_convert as pc
import country_converter as coco

# %%
cc = coco.CountryConverter()

# %%
df = pd.read_csv('Agrofood_co2_emission.csv\Agrofood_co2_emission.csv')
df = df.dropna()
df = df.drop(columns=["Pesticides Manufacturing","Savanna fires","Forest fires","Net Forest conversion","Fires in humid tropical forests","Food Household Consumption","Fires in organic soils","Manure left on Pasture","Manure applied to Soils","Fertilizers Manufacturing"])
df = df[df["Year"] >=2010]
df["Continent"]=cc.convert(names=df["Area"],to="continent")
df["Total_Population"] = df["Total Population - Female"] + df["Total Population - Male"]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\allanaabrego-ieg\AppData\Local\Temp\ipykernel_2632\2216460543.py:1: SyntaxWarning: invalid escape sequence '\A'
#   df = pd.read_csv('Agrofood_co2_emission.csv\Agrofood_co2_emission.csv')

# %%
df
# Out:
#           Area  Year  Crop Residues  Rice Cultivation  \
# 51     Albania  2010        39.5498        248.061497
# 52     Albania  2011        40.0999        248.061497
# 53     Albania  2012        39.9860        248.061497
# 54     Albania  2013        40.0653        248.061497
# 55     Albania  2014        39.8578        248.061497
# ...        ...   ...            ...               ...
# 6960  Zimbabwe  2016        70.9451          7.408800
# 6961  Zimbabwe  2017       108.6262          7.945800
# 6962  Zimbabwe  2018       109.9835          8.139900
# 6963  Zimbabwe  2019        45.4574          7.832200
# 6964  Zimbabwe  2020       108.3022          7.973300
#
#       Drained organic soils (CO2)  Food Transport  Forestland  Food Retail  \
# 51                       109.7740        277.1870  -1233.2859      71.1151
# 52                       109.8112        275.3115   -961.0391      75.1379
# 53                       109.8112        265.4062   -961.0391      76.6453
# 54                       109.1577        286.2621   -961.0391      85.9146
# 55                       109.1577        308.5878   -961.0391      93.1405
# ...                           ...             ...         ...          ...
# 6960                       0.0000        251.1465  76500.2982     443.0872
# 6961                       0.0000        255.7975  76500.2982     445.3881
# 6962                       0.0000        327.0897  76500.2982     492.8599
# 6963                       0.0000        290.1893  76500.2982     542.5922
# 6964                       0.0000        238.7639  76500.2982     568.0445
#
#       On-farm Electricity Use  Food Packaging  ...  Manure Management  \
# 51                     0.2406         27.3674  ...           482.3426
# 52                     0.9174         27.6027  ...           482.0319
# 53                     1.0605         29.7415  ...           487.3965
# 54                     1.2721         31.5296  ...           483.1922
# 55                     1.4056         45.3269  ...           491.2409
# ...                       ...             ...  ...                ...
# 6960                 428.4352         22.9108  ...           282.5994
# 6961                 304.7852         18.9857  ...           255.5900
# 6962                 346.8512         19.0570  ...           257.2735
# 6963                 350.2168         17.9514  ...           267.5224
# 6964                 350.2168         16.6754  ...           266.7316
#
#       On-farm energy use  Rural population  Urban population  \
# 51              235.4481         1406665.0         1533860.0
# 52              290.2752         1368297.0         1558362.0
# 53              244.5953         1333585.0         1586454.0
# 54              266.1464         1302236.0         1616742.0
# 55              299.1180         1272790.0         1647985.0
# ...                  ...               ...               ...
# 6960            417.3150        10934468.0         5215894.0
# 6961            398.1644        11201138.0         5328766.0
# 6962            465.7735        11465748.0         5447513.0
# 6963            444.2335        11725970.0         5571525.0
# 6964            444.2335        11980005.0         5700460.0
#
#       Total Population - Male  Total Population - Female  total_emission  \
# 51                  1459102.0                  1454297.0     3185.584797
# 52                  1453895.0                  1446759.0     3651.408297
# 53                  1450370.0                  1441822.0     3713.212497
# 54                  1448110.0                  1438905.0     3901.025997
# 55                  1446732.0                  1437370.0     3936.105597
# ...                       ...                        ...             ...
# 6960                6796658.0                  7656047.0    98491.026347
# 6961                6940631.0                  7810471.0    97159.311553
# 6962                7086002.0                  7966181.0    97668.308205
# 6963                7231989.0                  8122618.0    98988.062799
# 6964                7385220.0                  8284447.0    96505.221853
#
#       Average Temperature °C  Continent  Total_Population
# 51                  1.078500     Europe         2913399.0
# 52                  1.070500     Europe         2900654.0
# 53                  1.354583     Europe         2892192.0
# 54                  1.397417     Europe         2887015.0
# 55                  1.290250     Europe         2884102.0
# ...                      ...        ...               ...
# 6960                1.120250     Africa        14452705.0
# 6961                0.046500     Africa        14751102.0
# 6962                0.516333     Africa        15052183.0
# 6963                0.985667     Africa        15354607.0
# 6964                0.189000     Africa        15669667.0
#
# [1659 rows x 23 columns]

# %%
sns.set_theme(style="whitegrid")

# %%
sns.scatterplot(
    data=df,
    x="IPPU",
    y="total_emission",
    hue="Continent",       
    sizes=(50, 300),    
    palette="tab10"
)

plt.title("Relação entre IPPU e Emissões Totais por Continente")
plt.xlabel("IPPU")
plt.ylabel("Total de Emissões")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2) 
plt.show()

# %%
sns.barplot(data=df, x="Year", y="total_emission", hue="Continent", ci=None)
plt.title("Evolução das Emissões por Continente")
plt.xlabel("Year")
plt.ylabel("total_emission")
plt.show()
# Out:
# C:\Users\allanaabrego-ieg\AppData\Local\Temp\ipykernel_2632\4020233306.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="Year", y="total_emission", hue="Continent", ci=None)

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=df, x="Year", y="Average Temperature °C", hue="Continent", marker="o",ci=None)
plt.title("Evolução da Temperatura Média por Continente")
plt.xlabel("Year")
plt.ylabel("Average Temperature °C")
plt.show()
# Out:
# C:\Users\allanaabrego-ieg\AppData\Local\Temp\ipykernel_2632\967894195.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df, x="Year", y="Average Temperature °C", hue="Continent", marker="o",ci=None)

# %%
sns.scatterplot(
    data=df,
    x="total_emission",
    y="Average Temperature °C",
    hue="Continent"
)
plt.title("Relação Transporte de Comida x Emissões por Continente")
plt.show()

# %%
sns.scatterplot(
    data=df,
    x="total_emission",
    y="Food Transport",
    hue="Continent"
)
plt.title("Relação Transporte de Comida x Emissões por Continente")
plt.show()

# %%
sns.boxplot(
    data=df,
    x="Continent",          
    y="On-farm energy use"     
)
plt.yscale("log")
plt.title("Distribuição do uso de energia em fazendas por Continente")
plt.ylabel("On-farm energy use")
plt.xlabel("Continent")
plt.show()

# %%
sns.scatterplot(data=df,y="Total_Population",x="total_emission", hue="Continent")
plt.title("Relação entre população e emissões de carbono por continente")
plt.ylabel("Total_Population")
plt.xlabel("total_emission")
plt.show()
